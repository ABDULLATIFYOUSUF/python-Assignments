# %%
English = int(input("Enter your obtain marks in English : "))
Urdu = int(input("Enter your obtain marks in Urdu : "))
Math = int(input("Enter your obtain marks in Math : "))
Computer = int(input("Enter your obtain marks in Computer : "))
Islamiat = int(input("Enter your obtain marks in Islamiat : "))
obtainMarks = English + Urdu + Math + Computer + Islamiat
print("Your Obtain Marks are : ", obtainMarks)
percentage = obtainMarks / 500 * 100
print("Your percentage is : ", percentage, "%")
if percentage >= 80 and percentage <=100:
    print("Your Grade is : A+")
elif percentage >= 70 and percentage <=79:
    print("Your Grade is : A")
elif percentage >= 60 and percentage <=69:
    print("Your Grade is : B")
elif percentage >= 50 and percentage <=59:
    print("Your Grade is : C")
elif percentage >= 40 and percentage <=49:
    print("Your Grade is : D")
elif percentage >= 0 and percentage <40:
    print("You are Fail")
else:
    print("Invalid Marks Detail")
# Out:
# Enter your obtain marks in English :  10
# Enter your obtain marks in Urdu :  20
# Enter your obtain marks in Math :  30
# Enter your obtain marks in Computer :  40
# Enter your obtain marks in Islamiat :  10
# Your Obtain Marks are :  110
# Your percentage is :  22.0 %
# You are Fail
