# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Choose operation:")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
print("5. Power")

choice = input("Enter choice (1-5): ")

if choice == "1":
    print("Result:", num1 + num2)

elif choice == "2":
    print("Result:", num1 - num2)

elif choice == "3":
    print("Result:", num1 * num2)

elif choice == "4":
    print("Result:", num1 / num2)

elif choice == "5":
    print("Result:", num1 ** num2)

else:
    print("Invalid choice")
# Out:
# Enter first number:  5
# Enter second number:  5
# Choose operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Power
# Enter choice (1-5):  1
# Result: 10.0

# %%
list1 = [1, "hello", 5, "world"]

for item in list1:
    if type(item) == int:
        print("Numeric value found:", item)
# Out:
# Numeric value found: 1
# Numeric value found: 5

# %%
dictionary1 = {"name": "Abdul Latif", "age": 40}

dictionary1["city"] = "Karachi"

print(dictionary1)
# Out:
# {'name': 'Abdul Latif', 'age': 40, 'city': 'Karachi'}

# %%
dictionary2 = {"a": 10, "b": 20, "c": 30}

print(sum(dictionary2.values()))
# Out:
# 60

# %%
list1 = [1, 2, 3, 2, 4, 5, 1]

list2 = []

for item in list1:
    if list1.count(item) > 1:
        list2.append(item)

print("Duplicate values:", list2)
# Out:
# Duplicate values: [1, 2, 2, 1]
